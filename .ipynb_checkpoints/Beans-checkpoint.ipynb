# %%
# %matplotlib notebook

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
csv_path = "Resources/flavors_of_cacao.csv"
cacao_df = pd.read_csv(csv_path)
cacao_df.columns = ['Company', 'Brandname', 'REF', 'Review Date', 'Percent of Cacao', 'Company Location', 'Rating', 'Bean', 'Origin Location']
cacao_df.head()
# Out:
#     Company    Brandname   REF  Review Date Percent of Cacao Company Location  \
# 0  A. Morin  Agua Grande  1876         2016              63%           France
# 1  A. Morin        Kpime  1676         2015              70%           France
# 2  A. Morin       Atsane  1676         2015              70%           France
# 3  A. Morin        Akata  1680         2015              70%           France
# 4  A. Morin       Quilla  1704         2015              70%           France
#
#    Rating Bean Origin Location
# 0    3.75             Sao Tome
# 1    2.75                 Togo
# 2    3.00                 Togo
# 3    3.50                 Togo
# 4    3.50                 Peru

# %%
del cacao_df['REF']
cacao_df.head()
# Out:
#     Company    Brandname  Review Date Percent of Cacao Company Location  \
# 0  A. Morin  Agua Grande         2016              63%           France
# 1  A. Morin        Kpime         2015              70%           France
# 2  A. Morin       Atsane         2015              70%           France
# 3  A. Morin        Akata         2015              70%           France
# 4  A. Morin       Quilla         2015              70%           France
#
#    Rating Bean Origin Location
# 0    3.75             Sao Tome
# 1    2.75                 Togo
# 2    3.00                 Togo
# 3    3.50                 Togo
# 4    3.50                 Peru

# %%
beans = cacao_df['Bean'].unique()
print(len(beans))
# Out:
# 42

# %%
#munging and bucketing
cacao_df['Bean Type'] = cacao_df.Bean.str.split('(', n=1).str.get(0)
cacao_df['Bean Type'] = cacao_df['Bean Type'].replace({'Forastero ': 'Forastero', 'Criollo ': 'Criollo', 'Trinitario ': 'Trinitario',
                                                          'Criollo, Trinitario': 'Blend', 'Trinitario, Criollo': 'Blend', 'Criollo, Forastero': 'Blend',
                                                          'Trinitario, Forastero': 'Blend', 'Forastero, Trinitario': 'Blend', 'Blend-Forastero,Criollo': 'Blend'})

# %%
cacao_df['Bean Type'].value_counts()
# Out:
#                         887
# Trinitario              423
# Forastero               195
# Criollo                 171
# Blend                    95
# EET                       3
# Beniano                   3
# Matina                    3
# Nacional                  3
# Amazon mix                2
# Nacional                  2
# Amazon, ICS               2
# Criollo, +                1
# CCN51                     1
# Amazon                    1
# Trinitario, TCGA          1
# Trinitario, Nacional      1
# Name: Bean Type, dtype: int64

# %%
del cacao_df['Bean']
cacao_df.head()
# Out:
#     Company    Brandname  Review Date Percent of Cacao Company Location  \
# 0  A. Morin  Agua Grande         2016              63%           France
# 1  A. Morin        Kpime         2015              70%           France
# 2  A. Morin       Atsane         2015              70%           France
# 3  A. Morin        Akata         2015              70%           France
# 4  A. Morin       Quilla         2015              70%           France
#
#    Rating Origin Location Bean Type
# 0    3.75        Sao Tome
# 1    2.75            Togo
# 2    3.00            Togo
# 3    3.50            Togo
# 4    3.50            Peru

# %%
beans_df = cacao_df.loc[cacao_df['Bean Type'].isin(['Trinitario', 'Forastero','Criollo', 'Blend'])]
print(len(beans_df['Bean Type'].unique()))
beans_df.head()
# Out:
# 4
#      Company       Brandname  Review Date Percent of Cacao Company Location  \
# 5   A. Morin        Carenero         2014              70%           France
# 7   A. Morin    Sur del Lago         2014              70%           France
# 8   A. Morin  Puerto Cabello         2014              70%           France
# 11  A. Morin      Madagascar         2013              70%           France
# 17  A. Morin           Chuao         2013              70%           France
#
#     Rating Origin Location   Bean Type
# 5     2.75       Venezuela     Criollo
# 7     3.50       Venezuela     Criollo
# 8     3.75       Venezuela     Criollo
# 11    3.00      Madagascar     Criollo
# 17    4.00       Venezuela  Trinitario

# %%
# avg_pct_cacao = beans_df.groupby(["Bean Type"]).mean()["Percent of Cacao"]
# bean_type = beans_df.set_index(["Bean Type"]).groupby(["Bean Type"])

# bean_type.head()
# beans_df.groupby('Bean Type')['Percent of Cacao'].mean()

beans_df['Percent of Cacao'] = beans_df['Percent of Cacao'].str.replace('%', '')
beans_df['Percent of Cacao'] = beans_df[['Percent of Cacao']].apply(pd.to_numeric)
beans_df.head()
print(beans_df['Percent of Cacao'].mean())
cacao_pct_by_bean_type = round(beans_df.groupby('Bean Type')['Percent of Cacao'].mean(), 2)
print(cacao_pct_by_bean_type)
# Out:
# 71.85690045248869
# Bean Type
# Blend         71.49
# Criollo       71.91
# Forastero     72.28
# Trinitario    71.72
# Name: Percent of Cacao, dtype: float64
# C:\Users\brand\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel\__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\brand\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel\__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
beans_df['Percent of Cacao'].describe()
# Out:
# count    884.000000
# mean      71.856900
# std        6.145844
# min       50.000000
# 25%       70.000000
# 50%       70.000000
# 75%       75.000000
# max      100.000000
# Name: Percent of Cacao, dtype: float64

# %%
x_axis = beans_df['Bean Type']
y_axis = beans_df['Percent of Cacao'].mean()
# x_axis = cacao_pct_by_bean_type
# y_axis = round(beans_df.groupby('Bean Type')['Percent of Cacao'].mean(), 2)

# %%
plt.bar(x_axis, y_axis, color='r', alpha=0.5, align="center")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 884 artists>

# %%
plt.title("Average Percentage of Cacao in Chcocolates Made with Each Type of Bean")
plt.xlabel("Type of Bean")
plt.ylabel("Percentage of Cacao")
# Out:
# Text(64.6181,0.5,'Percentage of Cacao')
